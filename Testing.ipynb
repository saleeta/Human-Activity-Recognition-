# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot 
from pandas import read_csv
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import signal

name_sit='nothing_2.csv'
name_sft='nailbiting_11.csv'
name_std='eat_2.csv'
name_wlk='smonk_1.csv'

def load_file(filepath):
	dataframe = pd.read_csv('cleaned/done/'+filepath, header=0, delimiter=',')
    #dataframe = read_csv(filepath, header=None, delimiter=',')
	return dataframe

df1 = load_file(name_sit)
df2 = load_file(name_std)
df3 = load_file(name_sft)
df4 = load_file(name_wlk)

df1
# Out:
#            TimeStamp        Ax        Ay        Az        Gx        Gy  \
# 0      1554207782737 -9.447520 -0.359729  1.512537 -0.050067 -0.015979
# 1      1554207782756 -9.500193 -0.436343  1.589151 -0.074569 -0.021305
# 2      1554207782776 -9.581595 -0.398036  1.689708 -0.107592 -0.030893
# 3      1554207782797 -9.634268 -0.374094  1.847725 -0.132093 -0.034088
# 4      1554207782818 -9.500193 -0.259172  1.718438 -0.140615 -0.033023
# 5      1554207782836 -9.600749 -0.211288  1.890821 -0.136354 -0.035154
# 6      1554207782856 -9.562442 -0.240019  1.747169 -0.132093 -0.036219
# 7      1554207782877 -9.619903 -0.225654  1.924340 -0.137419 -0.029827
# 8      1554207782896 -9.605537 -0.364517  1.732803 -0.141680 -0.036219
# 9      1554207782916 -9.461885 -0.335787  1.991377 -0.147007 -0.034088
# 10     1554207782937 -9.562442 -0.311845  1.828572 -0.153398 -0.028762
# 11     1554207782957 -9.581595 -0.259172  1.876456 -0.170442 -0.018109
# ...

# %%
fig = plt.figure()
import time


ax1 = fig.add_subplot(1,1,1)
#plt.plot(df1.iloc[:1200,0],df1.iloc[:1200,1])
plt.plot(df2.iloc[:1200,0],df2.iloc[:1200,1])
#plt.plot(df2.iloc[50:-50,0],df2.iloc[50:-50,1])

#plt.plot(df1.iloc[200:-200,0],df1.iloc[200:-200,1])


#ax1.plot(df.iloc[50:-50,0],df.iloc[50:-50,1], color='red')
#plt.plot((df.iloc[80:-80,0],df.iloc[80:-80,1]), (df.iloc[60:-60,0],df.iloc[60:-60,1])); 
plt.show()
